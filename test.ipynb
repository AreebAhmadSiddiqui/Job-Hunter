# %%
import pandas as pd

# %%
job_data=pd.read_csv('Job_Data.csv')
job_data
# Out:
#                                           Title  \
# 0            developer Senior Software Engineer
# 1   Senior Software Engineer -  Robotic Process
# 2            Senior Software Engineer - Systems
# 3                      Senior Software Engineer
# 4                      Senior Software Engineer
# ..                                          ...
# 60                  Associate Software Engineer
# 61                     Junior Software Engineer
# 62                              DevOps Engineer
# 63                              React Developer
# 64                        Jr Software Developer
#
#                        Company Name  \
# 0                           Mphasis
# 1                        CitiusTech
# 2                           Mphasis
# 3                           Mphasis
# 4                           Mphasis
# ..                              ...
# 60            CloudVandana Solution
# 61  Midaas Telesoft Private Limited
# 62    Conference Technologies, Inc.
# ...

# %%
job_data['Job Description']
# Out:
# 0     Responsibilities •To architect, design and dev...
# 1     Responsibilities : Participating effectively i...
# 2     Role: Java Developer with Microservices, AWS c...
# 3     Role: React JS DeveloperLocation: Pune or Bang...
# 4     Role - RPA Senior EngineerWho are we looking f...
#                             ...
# 60    Open to new challenges and learning and flexib...
# 61    Experience with UNIX/Linux or Windows environm...
# 62    Work on a software development team to create ...
# 63    Experience in ReactJS/React Native (Required)....
# 64    The ability to communicate complex procedures ...
# Name: Job Description, Length: 65, dtype: object
